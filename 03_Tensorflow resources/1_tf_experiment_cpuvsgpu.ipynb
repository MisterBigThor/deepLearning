# %%
# %tensorflow_version 1.x
from __future__ import print_function
import numpy as np
import datetime
import tensorflow as tf
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# Bits: 3.200.000.000

# %%
# %%time
log_device_placement = True
n = 10
A = np.random.rand(10000, 10000).astype('float32')
B = np.random.rand(10000, 10000).astype('float32')
c1 = []
c2 = []
# Out:
# CPU times: user 2.05 s, sys: 368 ms, total: 2.42 s
# Wall time: 2.42 s

# %%
def matpow(M, n):
    if n < 1:
        return M
    else:
        return tf.matmul(M, matpow(M, n-1))

# %% [markdown]
# # **CPU Experiment 1**

# %%
# %%time
with tf.device('/cpu:0'):
    a = tf.placeholder(tf.float32, [10000, 10000])
    b = tf.placeholder(tf.float32, [10000, 10000])
    c1.append(matpow(a, n))
    c1.append(matpow(b, n))
    sum = tf.add_n(c1)

t1_1 = datetime.datetime.now()
with tf.Session(config=tf.ConfigProto(log_device_placement=log_device_placement)) as sess:
    sess.run(sum, {a:A, b:B})
t2_1 = datetime.datetime.now()
print("CPU computation time: " + str(t2_1-t1_1))
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7
#
# CPU computation time: 0:10:36.040085
# CPU times: user 20min 42s, sys: 1.8 s, total: 20min 44s
# Wall time: 10min 36s

# %% [markdown]
# # **Single GPU experiment 2**

# %%
# %%time
with tf.device('/gpu:0'):
    a = tf.placeholder(tf.float32, [10000, 10000])
    b = tf.placeholder(tf.float32, [10000, 10000])
    c2.append(matpow(a, n))
    c2.append(matpow(b, n))
    sum = tf.add_n(c2)

t1_2 = datetime.datetime.now()
with tf.Session(config=tf.ConfigProto(log_device_placement=log_device_placement)) as sess:
    sess.run(sum, {a:A, b:B})
t2_2 = datetime.datetime.now()
print("Single GPU computation time: " + str(t2_2-t1_2))
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7
#
# Single GPU computation time: 0:00:17.168431
# CPU times: user 9.52 s, sys: 7.66 s, total: 17.2 s
# Wall time: 17.2 s
