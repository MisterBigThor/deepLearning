# %% [markdown]
# **1. Import Pandas as pd and Numpy as np**

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# **2. Read the csv file**

# %%
sal = pd.read_csv('/content/drive/My Drive/Jedi/Python/Ejercicios/salaries.csv')

# %% [markdown]
# **3. Show the first elements 10 from the DataFrame**

# %%
sal.head(10)
# Out:
#    Id        EmployeeName  ...         Agency  Status
# 0   1      NATHANIEL FORD  ...  San Francisco     NaN
# 1   2        GARY JIMENEZ  ...  San Francisco     NaN
# 2   3      ALBERT PARDINI  ...  San Francisco     NaN
# 3   4   CHRISTOPHER CHONG  ...  San Francisco     NaN
# 4   5     PATRICK GARDNER  ...  San Francisco     NaN
# 5   6      DAVID SULLIVAN  ...  San Francisco     NaN
# 6   7           ALSON LEE  ...  San Francisco     NaN
# 7   8       DAVID KUSHNER  ...  San Francisco     NaN
# 8   9      MICHAEL MORRIS  ...  San Francisco     NaN
# 9  10  JOANNE HAYES-WHITE  ...  San Francisco     NaN
#
# [10 rows x 13 columns]

# %% [markdown]
# **4. Show the information of the DataFrame and its Description. Are there any null object or number ?**

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
sal.describe().transpose()
# Out:
#                      count          mean  ...         75%        max
# Id                148654.0  74327.500000  ...  111490.750  148654.00
# BasePay           148045.0  66325.448841  ...   94691.050  319275.01
# OvertimePay       148650.0   5066.059886  ...    4658.175  245131.88
# OtherPay          148650.0   3648.767297  ...    4236.065  400184.25
# Benefits          112491.0  25007.893151  ...   35566.855   96570.66
# TotalPay          148654.0  74768.321972  ...  105839.135  567595.43
# TotalPayBenefits  148654.0  93692.554811  ...  132876.450  567595.43
# Year              148654.0   2012.522643  ...    2014.000    2014.00
# Notes                  0.0           NaN  ...         NaN        NaN
# Status                 0.0           NaN  ...         NaN        NaN
#
# [10 rows x 8 columns]

# %% [markdown]
# **5. Find the Maximum Base Pay and OverTime Pay**

# %%
sal['BasePay'].mean()
# Out:
# 66325.44884050643

# %%
sal['OvertimePay'].max()
# Out:
# 245131.88

# %% [markdown]
# **6. Find all the information about the Employee Named JOSEPH DRISCOLL**

# %%
Josep = sal[sal['EmployeeName'] == 'JOSEPH DRISCOLL']
Josep
# Out:
#     Id     EmployeeName  ...         Agency  Status
# 24  25  JOSEPH DRISCOLL  ...  San Francisco     NaN
#
# [1 rows x 13 columns]

# %% [markdown]
# **7. Calculate the total Benefits that JOSEPH has**

# %%
Josep[['TotalPayBenefits','Benefits']].sum()
# Out:
# TotalPayBenefits    270324.91
# Benefits                 0.00
# dtype: float64

# %% [markdown]
# **8. Find who whas the Maximum and Minimum TotalPayBenefits**

# %%
sal[sal['TotalPayBenefits'] == sal['TotalPayBenefits'].max()]['EmployeeName'].values[0]
# Out:
# 'NATHANIEL FORD'

# %%
print(sal[sal['TotalPayBenefits'] == sal['TotalPayBenefits'].min()]['EmployeeName'].values[0])
print(sal['TotalPayBenefits'].min())
# Out:
# Joe Lopez
# -618.13

# %% [markdown]
# **9. Calculate the mean of the BasePay**

# %%
sal['BasePay'].mean()
# Out:
# 66325.44884050643

# %% [markdown]
# **10. How many different job titles do we have ?**

# %%
len(sal['JobTitle'].unique())
# Out:
# 2159

# %% [markdown]
# **11. Find the First JobTitles that are more common**

# %%
sal['JobTitle'].value_counts()[0:5]
#sal.sort_values(by = sal['JobTitle'].value_counts())
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %%
len(list(filter(lambda x: x == 1, sal[sal['Year'] == 2013]['JobTitle'].value_counts().sort_values())))
# Out:
# 202

# %%
a = sal[sal['Year']==2013]['JobTitle'].value_counts() == 1
sum(a)
# Out:
# 202

# %% [markdown]
# **13. How many chiefs do we have ?**

# %%
sum(sal['JobTitle'].apply(lambda x: 'chief' in x.lower() ))
# Out:
# 627

# %% [markdown]
# **14. Is there any correlation between the JobTitle's length and the BasePay that someone has ?**

# %%
sal['JobTitle'].apply(lambda x: len(x)).corr(sal['BasePay'])
# Out:
# -0.005059092342865208

# %% [markdown]
# **15. Get the mean of BasePay, OverTimePay and TotalPay for all the different JobTitles**

# %%
sal2 = sal.groupby('JobTitle').mean()[['BasePay', 'OvertimePay', 'TotalPay']]
sal2
# Out:
#                                                      BasePay  ...      TotalPay
# JobTitle                                                      ...
# ACCOUNT CLERK                                   43300.806506  ...  44035.664337
# ACCOUNTANT                                      46643.172000  ...  47429.268000
# ACCOUNTANT INTERN                               28732.663958  ...  29031.742917
# ACPO,JuvP, Juv Prob (SFERS)                     62290.780000  ...  62290.780000
# ACUPUNCTURIST                                   66374.400000  ...  67594.400000
# ...                                                      ...  ...           ...
# X-RAY LABORATORY AIDE                           47664.773077  ...  52705.880385
# X-Ray Laboratory Aide                           46086.387100  ...  50823.942700
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS  52609.910000  ...  53632.870000
# Youth Comm Advisor                              39077.957500  ...  41414.307500
# ...
