# %% [markdown]
# # Lista de ejercicios base

# %% [markdown]
# ### **1.- Implementa 3 funciones de activación y representalas gráficamente.**

# %% [markdown]
# ### **2.- Implementa 3 funciones de coste y prueba su funcionamiento.**

# %% [markdown]
# ### **3.- Implementa un perceptrón**
